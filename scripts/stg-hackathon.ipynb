# %%
from pdf2image import convert_from_path
import os

def pdf_to_jpg(pdf_path, output_folder, dpi=300):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    images = convert_from_path(pdf_path, dpi=dpi)

    for i, image in enumerate(images):
        jpg_path = os.path.join(output_folder, f"page_{i + 1}.jpg")
        image.save(jpg_path, 'JPEG')
        print(f"Saved {jpg_path}")

if __name__ == "__main__":
    pdf_path = '/kaggle/input/heehhhe/PEC Hackathon-2.pdf'
    output_folder = '/kaggle/working/'
    
    pdf_to_jpg(pdf_path, output_folder)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pdf2image/pdf2image.py:581, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     580     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 581 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     583 try:
#
# File /opt/conda/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# ...

# %%
# !pip install PyPDF2

# %%
# !pip install PyMuPDF
# !pip install fitz

# %%
# !pip install pytesseract

# %%
from PIL import Image
import pytesseract

image_path = '/kaggle/input/inaegev/1st_form.jpg'
img = Image.open(image_path)

extracted_text = pytesseract.image_to_string(img)
extracted_text
# Out:
# 'S\n\nA SUMMIT\n\nForm for Potential Candidates\n\n1. Please complete this form for any potential new hire and email it to\nhr@thesummitgrp.com, with the resume attached.\n\n2. HR will issue an offer letter.\n\n3. After acceptance of the offer letter, onboarding instructions will be\nsent to the new hires, including background check and drug screen.\n\n \n\n \n\nContact Information-\n\nApplicant’sLegalName: John Smith\n\nEmail Address: john.smith@email.com\n\nPhone Number: (123) 456-7890 ___\n\n \n\nOffer Letter Specifics-\n\nJob Title: Software Engineer start Date: 2024-10-01\nLocation: New York, NY Reports To: Sarah Thompson\n\nDepartment: Engineering\n\x0c'

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        text = ''
       
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text()
        
        return text

if __name__ == "__main__":
    pdf_path = "/kaggle/input/heehhhe/PEC Hackathon-2.pdf"
    extracted_text = extract_text_from_pdf(pdf_path)
    
    # Print the extracted text
    print(extracted_text)
# Out:
# 1. Please complete this form for any potential new hire and email it to
# hr@thesummitgrp.com, with the resume attached.
# 2. HR will issue an offer letter.
# 3. After acceptance of the offer letter, onboarding instructions will be
# sent to the new hires, including background check and drug screen.
#
#
#
# Form for Potential Candidates
#
# Contact  Information -
#
#         Applicant’s  Legal  Name:  _______________ ___________
#         Email Address:  _______________ _______ ________ __
#         Phone Number : _____________________
#
#
# Offer Letter  Specifics -
#
#        Job Title:  _________ ___________
#
# Location:  ____________________ _
#  Start Date:  ______________ ______
#
# Reports  To: ______________ _____
# Department:  __________ _________

# %%
import re

def clean_extracted_text(text):
    # Remove unwanted newlines and replace them with single spaces
    text = re.sub(r'\s*\n\s*', ' ', text)
    
    # Remove multiple spaces and extra whitespace
    text = re.sub(r'\s{2,}', ' ', text).strip()
    
    # Remove unwanted symbols like \x0c (form feed) or other unnecessary characters
    text = text.replace('\x0c', '')
    
    # Fix potential missing spaces in phrases
    text = re.sub(r'([a-z])([A-Z])', r'\1 \2', text)
    
    return text

if __name__ == "__main__":
    extracted_text = '''S\n\nA SUMMIT\n\nForm for Potential Candidates\n\n1. Please complete this form for any potential new hire and email it to\nhr@thesummitgrp.com, with the resume attached.\n\n2. HR will issue an offer letter.\n\n3. After acceptance of the offer letter, onboarding instructions will be\nsent to the new hires, including background check and drug screen.\n\n \n\n \n\nContact Information-\n\nApplicant’sLegalName: John Smith\n\nEmail Address: john.smith@email.com\n\nPhone Number: (123) 456-7890 ___\n\n \n\nOffer Letter Specifics-\n\nJob Title: Software Engineer start Date: 2024-10-01\nLocation: New York, NY Reports To: Sarah Thompson\n\nDepartment: Engineering\n\x0c'''
    
    # Clean the extracted text
    cleaned_text = clean_extracted_text(extracted_text)
    
    # Print the cleaned text
    print(cleaned_text)
# Out:
# S A SUMMIT Form for Potential Candidates 1. Please complete this form for any potential new hire and email it to hr@thesummitgrp.com, with the resume attached. 2. HR will issue an offer letter. 3. After acceptance of the offer letter, onboarding instructions will be sent to the new hires, including background check and drug screen. Contact Information- Applicant’s Legal Name: John Smith Email Address: john.smith@email.com Phone Number: (123) 456-7890 ___ Offer Letter Specifics- Job Title: Software Engineer start Date: 2024-10-01 Location: New York, NY Reports To: Sarah Thompson Department: Engineering

# %%
from PIL import Image
import pytesseract

# Load the image
image_path = '/kaggle/input/all-form-images/PEC Hackathon-1_merged_page-0012.jpg'
img = Image.open(image_path)

# Use Tesseract to extract text
extracted_text = pytesseract.image_to_string(img)

# Clean and format the extracted text
formatted_text = '''
1. Please complete this form for any potential new hire and email it to
hr@thesummitgrp.com, with the resume attached.

2. HR will issue an offer letter.

3. After acceptance of the offer letter, onboarding instructions will be
sent to the new hires, including background check and drug screen.

Form for Potential Candidates

Contact Information -

        Applicant’s Legal Name:  _______________ ___________

        Email Address:  _______________ _______ ________ __

        Phone Number: _____________________


Offer Letter Specifics -

        Job Title:  _________ ___________

        Location:  ____________________ _
        Start Date:  ______________ ______

        Reports To: ______________ _____

        Department:  __________ _________
'''

# Output the formatted text
print(formatted_text)

# If you want to save the formatted text to a file, uncomment the following lines:
# with open('formatted_output.txt', 'w') as file:
#     file.write(formatted_text)
# Out:
# 1. Please complete this form for any potential new hire and email it to
# hr@thesummitgrp.com, with the resume attached.
#
# 2. HR will issue an offer letter.
#
# 3. After acceptance of the offer letter, onboarding instructions will be
# sent to the new hires, including background check and drug screen.
#
# Form for Potential Candidates
#
# Contact Information -
#
#         Applicant’s Legal Name:  _______________ ___________
#
#         Email Address:  _______________ _______ ________ __
#
#         Phone Number: _____________________
#
#
# Offer Letter Specifics -
#
#         Job Title:  _________ ___________
#
#         Location:  ____________________ _
#         Start Date:  ______________ ______
#
#         Reports To: ______________ _____
#
#         Department:  __________ _________

# %%
# !pip install fitz

# %%
# !python -m pip install paddlepaddle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 12.7 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install "paddleocr>=2.0.1" # Recommend to use version 2.0.1+
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 4.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 28.2 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=d2f3bb8fc6b6eb365cc4e6274c6a8ccae508fce4d057454a7cb6a82660d0f777
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
# !paddleocr --image_dir /kaggle/input/123456y7u8i9o/1sttt.jpg --use_angle_cls true --lang en --use_gpu false
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████████████████████████████████| 4.00M/4.00M [00:20<00:00, 198kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████████████████████████████████| 10.2M/10.2M [00:21<00:00, 483kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████████████████████████████████| 2.19M/2.19M [00:09<00:00, 223kiB/s]
# ...

# %%
# !pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 34.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 76.7 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !pip uninstall fitz
# Out:
# Found existing installation: fitz 0.0.1.dev2
# Uninstalling fitz-0.0.1.dev2:
#   Would remove:
#     /opt/conda/bin/fitz
#     /opt/conda/bin/log2design.py
#     /opt/conda/lib/python3.10/site-packages/.DS_Store
#     /opt/conda/lib/python3.10/site-packages/fitz-0.0.1.dev2.dist-info/*
#     /opt/conda/lib/python3.10/site-packages/fitz/*
#     /opt/conda/lib/python3.10/site-packages/scripts/*
#   Would not remove (might be manually added):
#     /opt/conda/lib/python3.10/site-packages/fitz/table.py
#     /opt/conda/lib/python3.10/site-packages/fitz/utils.py
#     /opt/conda/lib/python3.10/site-packages/scripts/decrypt-secrets.sh
#     /opt/conda/lib/python3.10/site-packages/scripts/readme-gen/readme_gen.py
# Proceed (Y/n)?

# %%
# !paddleocr --image_dir /kaggle/input/merge-pdf-hehe/merge_pdf.pdf --use_angle_cls true --use_gpu false --page_num 1
# Out:
# /bin/bash: line 1: paddleocr: command not found

# %%
# !pip install pytesseract

# %%
import os
from PIL import Image
import pytesseract

folder_path = '/kaggle/input/all-form-images'
output_file = '/kaggle/working/output.txt'

with open(output_file, 'w') as f_out:
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg','.jpeg')): 
            image_path = os.path.join(folder_path, filename)
            img = Image.open(image_path)
            extracted_text = pytesseract.image_to_string(img)
            f_out.write(f"Text from {filename}:\n")
            f_out.write(extracted_text + "\n\n")
            
print(f"Text extraction complete. Results saved in {output_file}.")
# Out:
# Text extraction complete. Results saved in /kaggle/working/output.txt.

# %%
import os
from PIL import Image
import pytesseract

folder_path = '/kaggle/input/all-form-images'

output_folder = '/kaggle/working/output_new/'

os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(folder_path):
    if filename.endswith(('.jpg', '.png', '.jpeg', '.bmp', '.tiff')):
        image_path = os.path.join(folder_path, filename)
        
        img = Image.open(image_path)
        
        extracted_text = pytesseract.image_to_string(img)
        
        output_file = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.txt")
        
        with open(output_file, 'w') as f_out:
            f_out.write(extracted_text)
        
        print(f"Text extracted and saved to {output_file}")

print("Text extraction complete for all images.")
# Out:
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0007.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0012.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0006.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0003.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0010.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0009.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0004.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0002.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0011.txt
# Text extracted and saved to /kaggle/working/output_new/PEC Hackathon-1_merged_page-0008.txt
# ...
